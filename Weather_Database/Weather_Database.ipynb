# %%
# Import the dependencies
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import random
import timeit


# Import the requests library.
import requests

# Import the datetime module from the datetime library.
from datetime import datetime

# Import the API key.
from config import weather_api_key

# Use the citipy module to get the neareast city using the citipy module
from citipy import citipy

# %%
# Create a new set of 2,000 random latitudes and longitudes.
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
coordinates = list(lat_lngs)

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create a list for cities
cities = []

# %%
for coordinate in coordinates:   
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
          
    if city not in cities:
        cities.append(city)

len(cities)
# Out:
# 767

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1


# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1

    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date,
                          "Current Description": city_description})
                            

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 2 of Set 1 | dikson
# Processing Record 3 of Set 1 | bredasdorp
# Processing Record 4 of Set 1 | rikitea
# Processing Record 5 of Set 1 | requena
# Processing Record 6 of Set 1 | bluff
# Processing Record 7 of Set 1 | ribeira grande
# Processing Record 8 of Set 1 | tiradentes
# Processing Record 9 of Set 1 | tuktoyaktuk
# Processing Record 10 of Set 1 | east london
# Processing Record 11 of Set 1 | mataura
# Processing Record 12 of Set 1 | raudeberg
# Processing Record 13 of Set 1 | golyshmanovo
# Processing Record 14 of Set 1 | homer
# Processing Record 15 of Set 1 | yar-sale
# Processing Record 16 of Set 1 | grand centre
# City not found. Skipping...
# Processing Record 17 of Set 1 | punta arenas
# Processing Record 18 of Set 1 | castro
# Processing Record 19 of Set 1 | albany
# Processing Record 20 of Set 1 | oranjemund
# Processing Record 21 of Set 1 | shahrud
# Processing Record 22 of Set 1 | sobolevo
# Processing Record 23 of Set 1 | upernavik
# Processing Record 24 of Set 1 | abu samrah
# Processing Record 25 of Set 1 | masvingo
# Processing Record 26 of Set 1 | eufaula
# Processing Record 27 of Set 1 | chuy
# Processing Record 28 of Set 1 | bubaque
# Processing Record 29 of Set 1 | kapoeta
# Processing Record 30 of Set 1 | nioro
# Processing Record 31 of Set 1 | kavaratti
# Processing Record 32 of Set 1 | hermanus
# Processing Record 33 of Set 1 | chapais
# Processing Record 34 of Set 1 | puerto ayora
# Processing Record 35 of Set 1 | saldanha
# Processing Record 36 of Set 1 | cozumel
# Processing Record 37 of Set 1 | pangnirtung
# Processing Record 38 of Set 1 | kytlym
# City not found. Skipping...
# Processing Record 39 of Set 1 | port alfred
# Processing Record 40 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 41 of Set 1 | kapaa
# Processing Record 42 of Set 1 | xining
# Processing Record 43 of Set 1 | turbat
# Processing Record 44 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 45 of Set 1 | chase
# Processing Record 46 of Set 1 | isangel
# Processing Record 47 of Set 1 | san cristobal
# Processing Record 48 of Set 1 | sun valley
# Processing Record 49 of Set 1 | hobart
# Processing Record 50 of Set 1 | port elizabeth
# Processing Record 1 of Set 2 | celestun
# Processing Record 2 of Set 2 | lufilufi
# Processing Record 3 of Set 2 | pauini
# Processing Record 4 of Set 2 | tuatapere
# Processing Record 5 of Set 2 | omboue
# Processing Record 6 of Set 2 | ushuaia
# Processing Record 7 of Set 2 | rawson
# Processing Record 8 of Set 2 | resistencia
# Processing Record 9 of Set 2 | klaksvik
# Processing Record 10 of Set 2 | tiznit
# Processing Record 11 of Set 2 | georgetown
# Processing Record 12 of Set 2 | gillette
# Processing Record 13 of Set 2 | barrow
# Processing Record 14 of Set 2 | tanabe
# Processing Record 15 of Set 2 | zhezkazgan
# Processing Record 16 of Set 2 | chunskiy
# Processing Record 17 of Set 2 | busselton
# Processing Record 18 of Set 2 | redmond
# Processing Record 19 of Set 2 | coihaique
# Processing Record 20 of Set 2 | provideniya
# Processing Record 21 of Set 2 | cape town
# Processing Record 22 of Set 2 | rungata
# City not found. Skipping...
# Processing Record 23 of Set 2 | campoverde
# Processing Record 24 of Set 2 | qaanaaq
# Processing Record 25 of Set 2 | flinders
# Processing Record 26 of Set 2 | nguiu
# City not found. Skipping...
# Processing Record 27 of Set 2 | fairbanks
# Processing Record 28 of Set 2 | saskylakh
# Processing Record 29 of Set 2 | new norfolk
# Processing Record 30 of Set 2 | marcona
# City not found. Skipping...
# Processing Record 31 of Set 2 | maghama
# City not found. Skipping...
# Processing Record 32 of Set 2 | scarborough
# Processing Record 33 of Set 2 | nara
# Processing Record 34 of Set 2 | hambantota
# Processing Record 35 of Set 2 | kirakira
# Processing Record 36 of Set 2 | hilo
# Processing Record 37 of Set 2 | muros
# Processing Record 38 of Set 2 | hithadhoo
# Processing Record 39 of Set 2 | bilasipara
# Processing Record 40 of Set 2 | svetlaya
# Processing Record 41 of Set 2 | santa lucia
# Processing Record 42 of Set 2 | ixtapa
# Processing Record 43 of Set 2 | laguna
# Processing Record 44 of Set 2 | chokurdakh
# Processing Record 45 of Set 2 | port lincoln
# Processing Record 46 of Set 2 | sao joao da barra
# Processing Record 47 of Set 2 | chelno-vershiny
# Processing Record 48 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 49 of Set 2 | capelinha
# Processing Record 50 of Set 2 | presidencia roque saenz pena
# Processing Record 1 of Set 3 | brigantine
# Processing Record 2 of Set 3 | havre-saint-pierre
# Processing Record 3 of Set 3 | darien
# Processing Record 4 of Set 3 | yellowknife
# Processing Record 5 of Set 3 | thinadhoo
# Processing Record 6 of Set 3 | dingle
# Processing Record 7 of Set 3 | vaini
# Processing Record 8 of Set 3 | suntar
# Processing Record 9 of Set 3 | lompoc
# Processing Record 10 of Set 3 | carnarvon
# Processing Record 11 of Set 3 | ciudad real
# Processing Record 12 of Set 3 | manokwari
# Processing Record 13 of Set 3 | rio muerto
# Processing Record 14 of Set 3 | pevek
# Processing Record 15 of Set 3 | jamestown
# Processing Record 16 of Set 3 | atuona
# Processing Record 17 of Set 3 | airai
# Processing Record 18 of Set 3 | butaritari
# Processing Record 19 of Set 3 | namibe
# Processing Record 20 of Set 3 | saint-philippe
# Processing Record 21 of Set 3 | kenai
# Processing Record 22 of Set 3 | mountain home
# Processing Record 23 of Set 3 | chernoyerkovskaya
# Processing Record 24 of Set 3 | shelburne
# Processing Record 25 of Set 3 | rio brilhante
# Processing Record 26 of Set 3 | khatanga
# Processing Record 27 of Set 3 | inhambane
# Processing Record 28 of Set 3 | nortelandia
# Processing Record 29 of Set 3 | namatanai
# Processing Record 30 of Set 3 | ilulissat
# Processing Record 31 of Set 3 | nome
# Processing Record 32 of Set 3 | bathsheba
# Processing Record 33 of Set 3 | ust-maya
# Processing Record 34 of Set 3 | alofi
# Processing Record 35 of Set 3 | luderitz
# Processing Record 36 of Set 3 | emerald
# Processing Record 37 of Set 3 | bandarbeyla
# Processing Record 38 of Set 3 | fortuna
# Processing Record 39 of Set 3 | nanortalik
# Processing Record 40 of Set 3 | never
# Processing Record 41 of Set 3 | gat
# Processing Record 42 of Set 3 | vynohradove
# Processing Record 43 of Set 3 | la ronge
# Processing Record 44 of Set 3 | ngunguru
# Processing Record 45 of Set 3 | laukaa
# Processing Record 46 of Set 3 | catemaco
# Processing Record 47 of Set 3 | bolungarvik
# City not found. Skipping...
# Processing Record 48 of Set 3 | san patricio
# Processing Record 49 of Set 3 | sibolga
# Processing Record 50 of Set 3 | coahuayana
# Processing Record 1 of Set 4 | palabuhanratu
# City not found. Skipping...
# Processing Record 2 of Set 4 | road town
# Processing Record 3 of Set 4 | katsuura
# Processing Record 4 of Set 4 | nantucket
# Processing Record 5 of Set 4 | elverum
# Processing Record 6 of Set 4 | bethel
# Processing Record 7 of Set 4 | guerrero negro
# Processing Record 8 of Set 4 | ponta do sol
# Processing Record 9 of Set 4 | bhadrak
# Processing Record 10 of Set 4 | lynn haven
# Processing Record 11 of Set 4 | norman wells
# Processing Record 12 of Set 4 | tres arroyos
# Processing Record 13 of Set 4 | praya
# Processing Record 14 of Set 4 | batemans bay
# Processing Record 15 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 16 of Set 4 | cumanayagua
# Processing Record 17 of Set 4 | nizhniy baskunchak
# Processing Record 18 of Set 4 | naftah
# City not found. Skipping...
# Processing Record 19 of Set 4 | codrington
# Processing Record 20 of Set 4 | sunrise manor
# Processing Record 21 of Set 4 | ulaanbaatar
# Processing Record 22 of Set 4 | longyearbyen
# Processing Record 23 of Set 4 | waipawa
# Processing Record 24 of Set 4 | sredneuralsk
# Processing Record 25 of Set 4 | nichinan
# Processing Record 26 of Set 4 | balabac
# Processing Record 27 of Set 4 | faanui
# Processing Record 28 of Set 4 | port-gentil
# Processing Record 29 of Set 4 | sorvag
# City not found. Skipping...
# Processing Record 30 of Set 4 | pombas
# Processing Record 31 of Set 4 | latehar
# Processing Record 32 of Set 4 | revda
# Processing Record 33 of Set 4 | aquiraz
# Processing Record 34 of Set 4 | kindu
# Processing Record 35 of Set 4 | thompson
# Processing Record 36 of Set 4 | moose factory
# Processing Record 37 of Set 4 | callaguip
# Processing Record 38 of Set 4 | tezu
# Processing Record 39 of Set 4 | santa marta
# Processing Record 40 of Set 4 | vao
# Processing Record 41 of Set 4 | kathmandu
# Processing Record 42 of Set 4 | tuy hoa
# Processing Record 43 of Set 4 | ternate
# Processing Record 44 of Set 4 | pokhara
# Processing Record 45 of Set 4 | avarua
# Processing Record 46 of Set 4 | rocha
# Processing Record 47 of Set 4 | mahon
# Processing Record 48 of Set 4 | sorland
# Processing Record 49 of Set 4 | magomeni
# Processing Record 50 of Set 4 | indramayu
# Processing Record 1 of Set 5 | alvorada
# Processing Record 2 of Set 5 | valleyview
# Processing Record 3 of Set 5 | mogadishu
# Processing Record 4 of Set 5 | aykhal
# Processing Record 5 of Set 5 | padang
# Processing Record 6 of Set 5 | narsaq
# Processing Record 7 of Set 5 | grand river south east
# City not found. Skipping...
# Processing Record 8 of Set 5 | hovd
# Processing Record 9 of Set 5 | lata
# Processing Record 10 of Set 5 | kasongo-lunda
# Processing Record 11 of Set 5 | tasiilaq
# Processing Record 12 of Set 5 | bang sai
# Processing Record 13 of Set 5 | vallee-jonction
# City not found. Skipping...
# Processing Record 14 of Set 5 | havelock
# Processing Record 15 of Set 5 | mar del plata
# Processing Record 16 of Set 5 | zeya
# Processing Record 17 of Set 5 | lebu
# Processing Record 18 of Set 5 | los llanos de aridane
# Processing Record 19 of Set 5 | bintulu
# Processing Record 20 of Set 5 | kiunga
# Processing Record 21 of Set 5 | naze
# Processing Record 22 of Set 5 | chimoio
# Processing Record 23 of Set 5 | sladkovicovo
# Processing Record 24 of Set 5 | barentsburg
# City not found. Skipping...
# Processing Record 25 of Set 5 | darab
# Processing Record 26 of Set 5 | bambous virieux
# Processing Record 27 of Set 5 | kodiak
# Processing Record 28 of Set 5 | ola
# Processing Record 29 of Set 5 | port hardy
# Processing Record 30 of Set 5 | bairiki
# Processing Record 31 of Set 5 | qasigiannguit
# Processing Record 32 of Set 5 | poum
# Processing Record 33 of Set 5 | galgani
# City not found. Skipping...
# Processing Record 34 of Set 5 | ust-barguzin
# Processing Record 35 of Set 5 | praia da vitoria
# Processing Record 36 of Set 5 | makhinjauri
# Processing Record 37 of Set 5 | cherskiy
# Processing Record 38 of Set 5 | amderma
# City not found. Skipping...
# Processing Record 39 of Set 5 | springville
# Processing Record 40 of Set 5 | victoria
# Processing Record 41 of Set 5 | yenagoa
# Processing Record 42 of Set 5 | bonnyville
# Processing Record 43 of Set 5 | nola
# Processing Record 44 of Set 5 | bogorodskoye
# Processing Record 45 of Set 5 | manjacaze
# Processing Record 46 of Set 5 | souillac
# Processing Record 47 of Set 5 | comodoro rivadavia
# Processing Record 48 of Set 5 | haines junction
# Processing Record 49 of Set 5 | tawkar
# City not found. Skipping...
# Processing Record 50 of Set 5 | yuzhno-yeniseyskiy
# City not found. Skipping...
# Processing Record 1 of Set 6 | shaunavon
# Processing Record 2 of Set 6 | angoram
# Processing Record 3 of Set 6 | tromso
# Processing Record 4 of Set 6 | seoul
# Processing Record 5 of Set 6 | nuuk
# Processing Record 6 of Set 6 | lavrentiya
# Processing Record 7 of Set 6 | aklavik
# Processing Record 8 of Set 6 | arraial do cabo
# Processing Record 9 of Set 6 | matagami
# Processing Record 10 of Set 6 | pemba
# Processing Record 11 of Set 6 | altagracia de orituco
# Processing Record 12 of Set 6 | iqaluit
# Processing Record 13 of Set 6 | mgachi
# Processing Record 14 of Set 6 | olafsvik
# Processing Record 15 of Set 6 | sept-iles
# Processing Record 16 of Set 6 | aksu
# Processing Record 17 of Set 6 | cravo norte
# Processing Record 18 of Set 6 | black river
# Processing Record 19 of Set 6 | mahebourg
# Processing Record 20 of Set 6 | portland
# Processing Record 21 of Set 6 | port macquarie
# Processing Record 22 of Set 6 | vestmannaeyjar
# Processing Record 23 of Set 6 | tessalit
# Processing Record 24 of Set 6 | hay river
# Processing Record 25 of Set 6 | coxim
# Processing Record 26 of Set 6 | sentyabrskiy
# City not found. Skipping...
# Processing Record 27 of Set 6 | montivilliers
# Processing Record 28 of Set 6 | tura
# Processing Record 29 of Set 6 | torbay
# Processing Record 30 of Set 6 | coquimbo
# Processing Record 31 of Set 6 | nyurba
# Processing Record 32 of Set 6 | yulara
# Processing Record 33 of Set 6 | nabire
# Processing Record 34 of Set 6 | mount gambier
# Processing Record 35 of Set 6 | samarai
# Processing Record 36 of Set 6 | sao pedro do sul
# Processing Record 37 of Set 6 | santa ines
# Processing Record 38 of Set 6 | posse
# Processing Record 39 of Set 6 | ati
# Processing Record 40 of Set 6 | axim
# Processing Record 41 of Set 6 | biak
# Processing Record 42 of Set 6 | sao filipe
# Processing Record 43 of Set 6 | tiksi
# Processing Record 44 of Set 6 | itarema
# Processing Record 45 of Set 6 | labuan
# Processing Record 46 of Set 6 | naryan-mar
# Processing Record 47 of Set 6 | sur
# Processing Record 48 of Set 6 | lac du bonnet
# Processing Record 49 of Set 6 | camabatela
# Processing Record 50 of Set 6 | hofn
# Processing Record 1 of Set 7 | sao jose da coroa grande
# Processing Record 2 of Set 7 | tukrah
# Processing Record 3 of Set 7 | kavieng
# Processing Record 4 of Set 7 | grosuplje
# Processing Record 5 of Set 7 | altamira
# Processing Record 6 of Set 7 | iskateley
# Processing Record 7 of Set 7 | burnie
# Processing Record 8 of Set 7 | hecun
# Processing Record 9 of Set 7 | ilhabela
# Processing Record 10 of Set 7 | lagoa
# Processing Record 11 of Set 7 | hvammstangi
# City not found. Skipping...
# Processing Record 12 of Set 7 | esperance
# Processing Record 13 of Set 7 | manggar
# Processing Record 14 of Set 7 | doha
# Processing Record 15 of Set 7 | luau
# Processing Record 16 of Set 7 | ishigaki
# Processing Record 17 of Set 7 | clyde river
# Processing Record 18 of Set 7 | fartura
# Processing Record 19 of Set 7 | aripuana
# Processing Record 20 of Set 7 | banda aceh
# Processing Record 21 of Set 7 | kostenec
# City not found. Skipping...
# Processing Record 22 of Set 7 | kirya
# Processing Record 23 of Set 7 | kruisfontein
# Processing Record 24 of Set 7 | puerto escondido
# Processing Record 25 of Set 7 | jalu
# Processing Record 26 of Set 7 | mathbaria
# Processing Record 27 of Set 7 | makakilo city
# Processing Record 28 of Set 7 | camacha
# Processing Record 29 of Set 7 | tolaga bay
# Processing Record 30 of Set 7 | korla
# Processing Record 31 of Set 7 | phek
# Processing Record 32 of Set 7 | ballina
# Processing Record 33 of Set 7 | ust-kulom
# Processing Record 34 of Set 7 | krasne
# Processing Record 35 of Set 7 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 36 of Set 7 | vestbygda
# City not found. Skipping...
# Processing Record 37 of Set 7 | bandar
# Processing Record 38 of Set 7 | sangre grande
# Processing Record 39 of Set 7 | las vegas
# Processing Record 40 of Set 7 | machico
# Processing Record 41 of Set 7 | kaitangata
# Processing Record 42 of Set 7 | bollnas
# Processing Record 43 of Set 7 | eureka
# Processing Record 44 of Set 7 | santa isabel do rio negro
# Processing Record 45 of Set 7 | ewa beach
# Processing Record 46 of Set 7 | ambon
# Processing Record 47 of Set 7 | nelson bay
# Processing Record 48 of Set 7 | flin flon
# Processing Record 49 of Set 7 | canandaigua
# Processing Record 50 of Set 7 | cabo san lucas
# Processing Record 1 of Set 8 | tenextatiloyan
# City not found. Skipping...
# Processing Record 2 of Set 8 | bartica
# Processing Record 3 of Set 8 | aloleng
# Processing Record 4 of Set 8 | moron
# Processing Record 5 of Set 8 | fort nelson
# Processing Record 6 of Set 8 | hannibal
# Processing Record 7 of Set 8 | baykit
# Processing Record 8 of Set 8 | vila franca do campo
# Processing Record 9 of Set 8 | ust-tsilma
# Processing Record 10 of Set 8 | cidreira
# Processing Record 11 of Set 8 | mundo nuevo
# Processing Record 12 of Set 8 | grants
# Processing Record 13 of Set 8 | alice springs
# Processing Record 14 of Set 8 | srednekolymsk
# Processing Record 15 of Set 8 | yatou
# Processing Record 16 of Set 8 | viedma
# Processing Record 17 of Set 8 | ampanihy
# Processing Record 18 of Set 8 | gizo
# Processing Record 19 of Set 8 | farsund
# Processing Record 20 of Set 8 | kharan
# Processing Record 21 of Set 8 | coruripe
# Processing Record 22 of Set 8 | nouadhibou
# Processing Record 23 of Set 8 | channel-port aux basques
# Processing Record 24 of Set 8 | skiros
# City not found. Skipping...
# Processing Record 25 of Set 8 | yudong
# Processing Record 26 of Set 8 | khandbari
# Processing Record 27 of Set 8 | neuquen
# Processing Record 28 of Set 8 | lokosovo
# Processing Record 29 of Set 8 | cabra
# Processing Record 30 of Set 8 | mareeba
# Processing Record 31 of Set 8 | turukhansk
# Processing Record 32 of Set 8 | port blair
# Processing Record 33 of Set 8 | tarata
# Processing Record 34 of Set 8 | martapura
# Processing Record 35 of Set 8 | robertsport
# Processing Record 36 of Set 8 | syumsi
# Processing Record 37 of Set 8 | pennadam
# Processing Record 38 of Set 8 | sitka
# Processing Record 39 of Set 8 | brooks
# Processing Record 40 of Set 8 | marsa matruh
# Processing Record 41 of Set 8 | tutoia
# Processing Record 42 of Set 8 | sharanga
# Processing Record 43 of Set 8 | nijar
# Processing Record 44 of Set 8 | hirara
# Processing Record 45 of Set 8 | nouna
# Processing Record 46 of Set 8 | te anau
# Processing Record 47 of Set 8 | mezen
# Processing Record 48 of Set 8 | pombia
# Processing Record 49 of Set 8 | severnyy
# Processing Record 50 of Set 8 | geraldton
# Processing Record 1 of Set 9 | ketchikan
# Processing Record 2 of Set 9 | boma
# Processing Record 3 of Set 9 | unity
# Processing Record 4 of Set 9 | pangody
# Processing Record 5 of Set 9 | ende
# Processing Record 6 of Set 9 | moranbah
# Processing Record 7 of Set 9 | richards bay
# Processing Record 8 of Set 9 | kaoma
# Processing Record 9 of Set 9 | labrea
# Processing Record 10 of Set 9 | okhotsk
# Processing Record 11 of Set 9 | masakin
# Processing Record 12 of Set 9 | nouakchott
# Processing Record 13 of Set 9 | sumbe
# Processing Record 14 of Set 9 | shimoda
# Processing Record 15 of Set 9 | komsomolskiy
# Processing Record 16 of Set 9 | mallasamudram
# Processing Record 17 of Set 9 | garden city
# Processing Record 18 of Set 9 | alexandria
# Processing Record 19 of Set 9 | nizhneyansk
# City not found. Skipping...
# Processing Record 20 of Set 9 | lodwar
# Processing Record 21 of Set 9 | nizhniy odes
# Processing Record 22 of Set 9 | canyon
# Processing Record 23 of Set 9 | barbar
# City not found. Skipping...
# Processing Record 24 of Set 9 | newport
# Processing Record 25 of Set 9 | cabedelo
# Processing Record 26 of Set 9 | pisco
# Processing Record 27 of Set 9 | tabou
# Processing Record 28 of Set 9 | san ciro de acosta
# Processing Record 29 of Set 9 | chulman
# Processing Record 30 of Set 9 | qaqortoq
# Processing Record 31 of Set 9 | aginskoye
# Processing Record 32 of Set 9 | caravelas
# Processing Record 33 of Set 9 | leningradskiy
# Processing Record 34 of Set 9 | russell
# Processing Record 35 of Set 9 | cururupu
# Processing Record 36 of Set 9 | bastia
# Processing Record 37 of Set 9 | touros
# Processing Record 38 of Set 9 | ponta delgada
# Processing Record 39 of Set 9 | benicarlo
# Processing Record 40 of Set 9 | kailua
# Processing Record 41 of Set 9 | skelleftea
# Processing Record 42 of Set 9 | matadi
# Processing Record 43 of Set 9 | asau
# Processing Record 44 of Set 9 | tsihombe
# City not found. Skipping...
# Processing Record 45 of Set 9 | caetite
# Processing Record 46 of Set 9 | salinopolis
# Processing Record 47 of Set 9 | port augusta
# Processing Record 48 of Set 9 | jujuy
# City not found. Skipping...
# Processing Record 49 of Set 9 | mnogovershinnyy
# Processing Record 50 of Set 9 | yomitan
# City not found. Skipping...
# Processing Record 1 of Set 10 | ocean city
# Processing Record 2 of Set 10 | dobresti
# Processing Record 3 of Set 10 | blythe
# Processing Record 4 of Set 10 | taikang
# Processing Record 5 of Set 10 | mount isa
# Processing Record 6 of Set 10 | palmer
# Processing Record 7 of Set 10 | saleaula
# City not found. Skipping...
# Processing Record 8 of Set 10 | verkhnyaya inta
# Processing Record 9 of Set 10 | kluang
# Processing Record 10 of Set 10 | farafangana
# Processing Record 11 of Set 10 | mentok
# City not found. Skipping...
# Processing Record 12 of Set 10 | vangaindrano
# Processing Record 13 of Set 10 | tual
# Processing Record 14 of Set 10 | yarada
# Processing Record 15 of Set 10 | sorong
# Processing Record 16 of Set 10 | mandera
# Processing Record 17 of Set 10 | constitucion
# Processing Record 18 of Set 10 | nikolskoye
# Processing Record 19 of Set 10 | betamcherla
# Processing Record 20 of Set 10 | dunedin
# Processing Record 21 of Set 10 | miguel auza
# Processing Record 22 of Set 10 | nicoya
# Processing Record 23 of Set 10 | dali
# Processing Record 24 of Set 10 | yerbogachen
# Processing Record 25 of Set 10 | am timan
# Processing Record 26 of Set 10 | chagda
# City not found. Skipping...
# Processing Record 27 of Set 10 | teneguiban
# City not found. Skipping...
# Processing Record 28 of Set 10 | batsfjord
# Processing Record 29 of Set 10 | ivybridge
# Processing Record 30 of Set 10 | paidha
# Processing Record 31 of Set 10 | hami
# Processing Record 32 of Set 10 | launceston
# Processing Record 33 of Set 10 | zaysan
# Processing Record 34 of Set 10 | skjervoy
# Processing Record 35 of Set 10 | thilogne
# City not found. Skipping...
# Processing Record 36 of Set 10 | semnan
# Processing Record 37 of Set 10 | corsicana
# Processing Record 38 of Set 10 | hasaki
# Processing Record 39 of Set 10 | saint-jean-de-luz
# Processing Record 40 of Set 10 | mariinskiy posad
# Processing Record 41 of Set 10 | ancud
# Processing Record 42 of Set 10 | awbari
# Processing Record 43 of Set 10 | berlevag
# Processing Record 44 of Set 10 | vostok
# Processing Record 45 of Set 10 | hualmay
# Processing Record 46 of Set 10 | kieta
# Processing Record 47 of Set 10 | mungwi
# Processing Record 48 of Set 10 | yaan
# Processing Record 49 of Set 10 | dharchula
# Processing Record 50 of Set 10 | lorengau
# Processing Record 1 of Set 11 | pundaguitan
# Processing Record 2 of Set 11 | bengkulu
# Processing Record 3 of Set 11 | usta muhammad
# Processing Record 4 of Set 11 | vaitupu
# City not found. Skipping...
# Processing Record 5 of Set 11 | grootfontein
# Processing Record 6 of Set 11 | arlit
# Processing Record 7 of Set 11 | ipixuna
# Processing Record 8 of Set 11 | horni benesov
# Processing Record 9 of Set 11 | karpathos
# Processing Record 10 of Set 11 | basoko
# Processing Record 11 of Set 11 | pangoa
# Processing Record 12 of Set 11 | puerto leguizamo
# Processing Record 13 of Set 11 | broken hill
# Processing Record 14 of Set 11 | saint-augustin
# Processing Record 15 of Set 11 | ostrovnoy
# Processing Record 16 of Set 11 | krasnoselkup
# Processing Record 17 of Set 11 | abdulino
# Processing Record 18 of Set 11 | svetlogorsk
# Processing Record 19 of Set 11 | nizwa
# Processing Record 20 of Set 11 | ormara
# Processing Record 21 of Set 11 | hauterive
# Processing Record 22 of Set 11 | shubarkuduk
# Processing Record 23 of Set 11 | pandan
# Processing Record 24 of Set 11 | novovarshavka
# Processing Record 25 of Set 11 | pinyug
# Processing Record 26 of Set 11 | dolores
# Processing Record 27 of Set 11 | college
# Processing Record 28 of Set 11 | iralaya
# Processing Record 29 of Set 11 | fare
# Processing Record 30 of Set 11 | chipinge
# Processing Record 31 of Set 11 | rio gallegos
# Processing Record 32 of Set 11 | ust-ishim
# Processing Record 33 of Set 11 | half moon bay
# Processing Record 34 of Set 11 | kendari
# Processing Record 35 of Set 11 | constantine
# Processing Record 36 of Set 11 | kalengwa
# Processing Record 37 of Set 11 | segarcea
# Processing Record 38 of Set 11 | hammerfest
# Processing Record 39 of Set 11 | broome
# Processing Record 40 of Set 11 | batagay
# Processing Record 41 of Set 11 | chinsali
# Processing Record 42 of Set 11 | le port
# Processing Record 43 of Set 11 | santa vitoria do palmar
# Processing Record 44 of Set 11 | taburi
# City not found. Skipping...
# Processing Record 45 of Set 11 | itahari
# City not found. Skipping...
# Processing Record 46 of Set 11 | pavlovsk
# Processing Record 47 of Set 11 | kaihua
# Processing Record 48 of Set 11 | traverse city
# Processing Record 49 of Set 11 | goderich
# Processing Record 50 of Set 11 | sakaiminato
# Processing Record 1 of Set 12 | rosarito
# Processing Record 2 of Set 12 | dekoa
# City not found. Skipping...
# Processing Record 3 of Set 12 | cap malheureux
# Processing Record 4 of Set 12 | kosh-agach
# Processing Record 5 of Set 12 | meulaboh
# Processing Record 6 of Set 12 | magdagachi
# Processing Record 7 of Set 12 | vavatenina
# Processing Record 8 of Set 12 | tautira
# Processing Record 9 of Set 12 | havoysund
# Processing Record 10 of Set 12 | tsabong
# Processing Record 11 of Set 12 | karaul
# City not found. Skipping...
# Processing Record 12 of Set 12 | okha
# Processing Record 13 of Set 12 | calvinia
# Processing Record 14 of Set 12 | mae sai
# Processing Record 15 of Set 12 | vila velha
# Processing Record 16 of Set 12 | kalcheva
# Processing Record 17 of Set 12 | harper
# Processing Record 18 of Set 12 | anadyr
# Processing Record 19 of Set 12 | adrar
# Processing Record 20 of Set 12 | severo-kurilsk
# Processing Record 21 of Set 12 | saint-pierre
# Processing Record 22 of Set 12 | mandurah
# Processing Record 23 of Set 12 | kijang
# Processing Record 24 of Set 12 | kuryk
# Processing Record 25 of Set 12 | damghan
# Processing Record 26 of Set 12 | husavik
# Processing Record 27 of Set 12 | douglas
# Processing Record 28 of Set 12 | yantongshan
# Processing Record 29 of Set 12 | formoso do araguaia
# City not found. Skipping...
# Processing Record 30 of Set 12 | sinnamary
# Processing Record 31 of Set 12 | beyneu
# Processing Record 32 of Set 12 | khandyga
# Processing Record 33 of Set 12 | longkou
# Processing Record 34 of Set 12 | suez
# Processing Record 35 of Set 12 | aksarka
# Processing Record 36 of Set 12 | nipawin
# Processing Record 37 of Set 12 | grindavik
# Processing Record 38 of Set 12 | solnechnyy
# Processing Record 39 of Set 12 | cayenne
# Processing Record 40 of Set 12 | tsaratanana
# Processing Record 41 of Set 12 | bokovskaya
# Processing Record 42 of Set 12 | hakone
# Processing Record 43 of Set 12 | dwarka
# Processing Record 44 of Set 12 | crab hill
# City not found. Skipping...
# Processing Record 45 of Set 12 | westport
# Processing Record 46 of Set 12 | lawton
# Processing Record 47 of Set 12 | dukat
# Processing Record 48 of Set 12 | quesnel
# Processing Record 49 of Set 12 | zhigansk
# Processing Record 50 of Set 12 | ye
# City not found. Skipping...
# Processing Record 1 of Set 13 | beloha
# Processing Record 2 of Set 13 | kununurra
# Processing Record 3 of Set 13 | boa vista
# Processing Record 4 of Set 13 | amberley
# Processing Record 5 of Set 13 | sioux lookout
# Processing Record 6 of Set 13 | sondrio
# Processing Record 7 of Set 13 | goulburn
# Processing Record 8 of Set 13 | karratha
# Processing Record 9 of Set 13 | morant bay
# Processing Record 10 of Set 13 | itacoatiara
# Processing Record 11 of Set 13 | atambua
# Processing Record 12 of Set 13 | kamloops
# Processing Record 13 of Set 13 | vardo
# Processing Record 14 of Set 13 | tsybli
# Processing Record 15 of Set 13 | mukhen
# Processing Record 16 of Set 13 | pangkalanbuun
# Processing Record 17 of Set 13 | gazanjyk
# Processing Record 18 of Set 13 | kamenskoye
# City not found. Skipping...
# Processing Record 19 of Set 13 | taoudenni
# Processing Record 20 of Set 13 | general roca
# Processing Record 21 of Set 13 | suhbaatar
# Processing Record 22 of Set 13 | dongsheng
# Processing Record 23 of Set 13 | balimo
# City not found. Skipping...
# Processing Record 24 of Set 13 | tutayev
# Processing Record 25 of Set 13 | akureyri
# Processing Record 26 of Set 13 | stephenville
# Processing Record 27 of Set 13 | jiazi
# Processing Record 28 of Set 13 | negele
# City not found. Skipping...
# Processing Record 29 of Set 13 | buala
# Processing Record 30 of Set 13 | kutum
# Processing Record 31 of Set 13 | ouesso
# Processing Record 32 of Set 13 | tiarei
# Processing Record 33 of Set 13 | key largo
# Processing Record 34 of Set 13 | tevaitoa
# Processing Record 35 of Set 13 | canaries
# Processing Record 36 of Set 13 | belmonte
# Processing Record 37 of Set 13 | brae
# Processing Record 38 of Set 13 | zahirabad
# Processing Record 39 of Set 13 | cam ranh
# Processing Record 40 of Set 13 | chicama
# Processing Record 41 of Set 13 | haldia
# Processing Record 42 of Set 13 | bongandanga
# Processing Record 43 of Set 13 | wenling
# Processing Record 44 of Set 13 | porto velho
# Processing Record 45 of Set 13 | chernyshevskiy
# Processing Record 46 of Set 13 | san fernando
# Processing Record 47 of Set 13 | rusape
# Processing Record 48 of Set 13 | verkhoyansk
# Processing Record 49 of Set 13 | marrakesh
# Processing Record 50 of Set 13 | vera cruz
# Processing Record 1 of Set 14 | salalah
# Processing Record 2 of Set 14 | paamiut
# Processing Record 3 of Set 14 | shenjiamen
# Processing Record 4 of Set 14 | north myrtle beach
# Processing Record 5 of Set 14 | baruun-urt
# Processing Record 6 of Set 14 | saint george
# Processing Record 7 of Set 14 | aguililla
# Processing Record 8 of Set 14 | kourou
# Processing Record 9 of Set 14 | grand gaube
# Processing Record 10 of Set 14 | mitchell
# Processing Record 11 of Set 14 | kamaishi
# Processing Record 12 of Set 14 | noumea
# Processing Record 13 of Set 14 | divnomorskoye
# Processing Record 14 of Set 14 | lingao
# Processing Record 15 of Set 14 | parana
# Processing Record 16 of Set 14 | kheri
# Processing Record 17 of Set 14 | montelibano
# Processing Record 18 of Set 14 | russas
# Processing Record 19 of Set 14 | svetlyy
# Processing Record 20 of Set 14 | emba
# Processing Record 21 of Set 14 | estelle
# Processing Record 22 of Set 14 | tigil
# Processing Record 23 of Set 14 | bereda
# Processing Record 24 of Set 14 | champerico
# Processing Record 25 of Set 14 | flagstaff
# Processing Record 26 of Set 14 | jardim
# Processing Record 27 of Set 14 | bilibino
# Processing Record 28 of Set 14 | ahipara
# Processing Record 29 of Set 14 | bilma
# Processing Record 30 of Set 14 | severobaykalsk
# Processing Record 31 of Set 14 | iquitos
# Processing Record 32 of Set 14 | taywarah
# Processing Record 33 of Set 14 | kawalu
# Processing Record 34 of Set 14 | atlantic city
# Processing Record 35 of Set 14 | shingu
# Processing Record 36 of Set 14 | puerto lempira
# Processing Record 37 of Set 14 | george town
# Processing Record 38 of Set 14 | arandis
# Processing Record 39 of Set 14 | anahuac
# Processing Record 40 of Set 14 | mandalgovi
# Processing Record 41 of Set 14 | xunchang
# Processing Record 42 of Set 14 | imbituba
# Processing Record 43 of Set 14 | samusu
# City not found. Skipping...
# Processing Record 44 of Set 14 | sabang
# Processing Record 45 of Set 14 | vanimo
# Processing Record 46 of Set 14 | sunbury
# Processing Record 47 of Set 14 | pelym
# Processing Record 48 of Set 14 | tarakan
# Processing Record 49 of Set 14 | coral springs
# Processing Record 50 of Set 14 | muyezerskiy
# Processing Record 1 of Set 15 | nalut
# Processing Record 2 of Set 15 | kibala
# Processing Record 3 of Set 15 | honningsvag
# Processing Record 4 of Set 15 | cotacachi
# Processing Record 5 of Set 15 | samorin
# Processing Record 6 of Set 15 | san vicente
# Processing Record 7 of Set 15 | gasa
# Processing Record 8 of Set 15 | matara
# Processing Record 9 of Set 15 | yanchukan
# City not found. Skipping...
# Processing Record 10 of Set 15 | auki
# Processing Record 11 of Set 15 | esso
# Processing Record 12 of Set 15 | anar darreh
# City not found. Skipping...
# Processing Record 13 of Set 15 | todos santos
# Processing Record 14 of Set 15 | faya
# Processing Record 15 of Set 15 | arnstadt
# Processing Record 16 of Set 15 | carballo
# Processing Record 17 of Set 15 | suicheng
# Processing Record 18 of Set 15 | monte azul
# Processing Record 19 of Set 15 | gurupa
# Processing Record 20 of Set 15 | bodden town
# Processing Record 21 of Set 15 | peno
# Processing Record 22 of Set 15 | walvis bay
# Processing Record 23 of Set 15 | craig
# Processing Record 24 of Set 15 | macusani
# Processing Record 25 of Set 15 | tandil
# Processing Record 26 of Set 15 | amurzet
# Processing Record 27 of Set 15 | abu dhabi
# Processing Record 28 of Set 15 | lubango
# Processing Record 29 of Set 15 | tsiroanomandidy
# Processing Record 30 of Set 15 | fukue
# Processing Record 31 of Set 15 | trairi
# Processing Record 32 of Set 15 | alta floresta
# Processing Record 33 of Set 15 | mangla
# Processing Record 34 of Set 15 | tungkang
# City not found. Skipping...
# Processing Record 35 of Set 15 | paradwip
# City not found. Skipping...
# Processing Record 36 of Set 15 | tonj
# Processing Record 37 of Set 15 | chongwe
# Processing Record 38 of Set 15 | puerto cabezas
# Processing Record 39 of Set 15 | houma
# Processing Record 40 of Set 15 | kirkwall
# Processing Record 41 of Set 15 | warqla
# City not found. Skipping...
# Processing Record 42 of Set 15 | margate
# Processing Record 43 of Set 15 | babanusah
# City not found. Skipping...
# Processing Record 44 of Set 15 | chumikan
# Processing Record 45 of Set 15 | ahwa
# Processing Record 46 of Set 15 | shetpe
# Processing Record 47 of Set 15 | abu kamal
# Processing Record 48 of Set 15 | is
# City not found. Skipping...
# Processing Record 49 of Set 15 | talnakh
# Processing Record 50 of Set 15 | lamu
# Processing Record 1 of Set 16 | reo
# Processing Record 2 of Set 16 | novyy urgal
# Processing Record 3 of Set 16 | la moncada
# Processing Record 4 of Set 16 | vestmanna
# Processing Record 5 of Set 16 | madras
# Processing Record 6 of Set 16 | bani walid
# Processing Record 7 of Set 16 | bambari
# Processing Record 8 of Set 16 | chegdomyn
# Processing Record 9 of Set 16 | mrirt
# City not found. Skipping...
# Processing Record 10 of Set 16 | mayumba
# Processing Record 11 of Set 16 | fairlie
# Processing Record 12 of Set 16 | bontang
# Processing Record 13 of Set 16 | ndele
# Processing Record 14 of Set 16 | maturin
# Processing Record 15 of Set 16 | la seyne-sur-mer
# Processing Record 16 of Set 16 | tam ky
# Processing Record 17 of Set 16 | port hedland
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0          Dikson  73.5069   80.5464      9.07        87          98
# 1      Bredasdorp -34.5322   20.0403     56.28        76          39
# 2         Rikitea -23.1203 -134.9692     74.82        82          98
# 3         Requena  39.4883   -1.1004     56.98        78           0
# 4           Bluff -46.6000  168.3333     51.57        93         100
# 5  Ribeira Grande  38.5167  -28.7000     68.40        73          75
# 6      Tiradentes -21.1103  -44.1781     81.01        60          76
# 7     Tuktoyaktuk  69.4541 -133.0374     28.40        93          75
# 8     East London -33.0153   27.9116     62.17        66          49
# 9         Mataura -46.1927  168.8643     51.31        96         100
#
#    Wind Speed Country                 Date Current Description
# 0       12.53      RU  2021-10-23 19:35:33     overcast clouds
# 1        3.44      ZA  2021-10-23 19:35:34    scattered clouds
# 2       20.58      PF  2021-10-23 19:44:21     overcast clouds
# 3        2.26      ES  2021-10-23 19:44:35           clear sky
# 4        3.58      NZ  2021-10-23 19:44:36          light rain
# 5        0.00      PT  2021-10-23 19:44:36       broken clouds
# 6        4.12      BR  2021-10-23 19:44:37       broken clouds
# 7        9.22      CA  2021-10-23 19:44:37       broken clouds
# 8       20.87      ZA  2021-10-23 19:35:37    scattered clouds
# 9        0.27      NZ  2021-10-23 19:35:37          light rain

# %%
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
city_data_df = city_data_df[new_column_order]
city_data_df
# Out:
#                  City Country      Lat       Lng  Max Temp  Humidity  \
# 0              Dikson      RU  73.5069   80.5464      9.07        87
# 1          Bredasdorp      ZA -34.5322   20.0403     56.28        76
# 2             Rikitea      PF -23.1203 -134.9692     74.82        82
# 3             Requena      ES  39.4883   -1.1004     56.98        78
# 4               Bluff      NZ -46.6000  168.3333     51.57        93
# ..                ...     ...      ...       ...       ...       ...
# 703             Ndele      CF   8.4109   20.6473     69.13        93
# 704           Maturin      VE   9.7500  -63.1767     79.43        88
# 705  La Seyne-Sur-Mer      FR  43.0982    5.8847     63.88        73
# 706            Tam Ky      VN  15.5667  108.4833     71.58        92
# 707      Port Hedland      AU -20.3167  118.5667     75.25        38
#
#      Cloudiness  Wind Speed Current Description
# 0            98       12.53     overcast clouds
# 1            39        3.44    scattered clouds
# 2            98       20.58     overcast clouds
# 3             0        2.26           clear sky
# 4           100        3.58          light rain
# ..          ...         ...                 ...
# 703         100        2.84          light rain
# 704          93        8.48     overcast clouds
# 705           0        6.53           clear sky
# 706         100       10.13       moderate rain
# 707         100        5.75     overcast clouds
#
# [708 rows x 9 columns]

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"

# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
